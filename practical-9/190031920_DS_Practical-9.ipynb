# %% [markdown]
# # 190031920
# # A Nikhil Reddy
# # DS Practical 9

# %%
import pandas as pd

# %%
weatherdata = pd.read_csv('vijandhydweather.csv')
weatherdata
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>day</th>
#       <th>Vijayawada</th>
#       <th>Hyderabad</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>Sunny</td>
#       <td>Sunny</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>Cloudy</td>
#       <td>Cloudy</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>Sunny</td>
#       <td>Cloudy</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>Cloudy</td>
#       <td>Cloudy</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>Sunny</td>
# ...

# %%
index = ['Vijayawada-Sunny', 'Vijayawada-Cloudy', 'Vijayawada-Rainy', 'Marginal-probability']
columns = ['Hyderabad-Sunny', 'Hyderabad-Cloudy', 'Hyderabad-Rainy', 'Marginal-probability']
probabilityTable = pd.DataFrame(index=index, columns=columns)
probabilityTable
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Hyderabad-Sunny</th>
#       <th>Hyderabad-Cloudy</th>
#       <th>Hyderabad-Rainy</th>
#       <th>Marginal-probability</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Vijayawada-Sunny</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Vijayawada-Cloudy</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Vijayawada-Rainy</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
# ...

# %%
counterss = countersc = countersr = 0
countercs = countercc = countercr = 0
counterrs = counterrc = counterrr = 0
weatherdatalen = len(weatherdata.index)
for i in range(weatherdatalen):
    if weatherdata.iat[i, 1] == "Sunny":
        if weatherdata.iat[i, 2] == "Sunny" :
            counterss+=1
        elif weatherdata.iat[i, 2] == "Cloudy" :
            countersc+=1
        elif weatherdata.iat[i, 2] == "Rainy" :
            countersr+=1
    if weatherdata.iat[i, 1] == "Cloudy":
        if weatherdata.iat[i, 2] == "Sunny" :
            countercs+=1
        elif weatherdata.iat[i, 2] == "Cloudy" :
            countercc+=1
        elif weatherdata.iat[i, 2] == "Rainy" :
            countercr+=1
    if weatherdata.iat[i, 1] == "Rainy":
        if weatherdata.iat[i, 2] == "Sunny" :
            counterrs+=1
        elif weatherdata.iat[i, 2] == "Cloudy" :
            counterrc+=1
        elif weatherdata.iat[i, 2] == "Rainy" :
            counterrr+=1

# %%
probabilityTable.iat[0, 0] = counterss
probabilityTable.iat[0, 1] = countersc
probabilityTable.iat[0, 2] = countersr
probabilityTable.iat[1, 0] = countercs
probabilityTable.iat[1, 1] = countercc
probabilityTable.iat[1, 2] = countercr
probabilityTable.iat[2, 0] = counterrs
probabilityTable.iat[2, 1] = counterrc
probabilityTable.iat[2, 2] = counterrr
probabilityTable
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Hyderabad-Sunny</th>
#       <th>Hyderabad-Cloudy</th>
#       <th>Hyderabad-Rainy</th>
#       <th>Marginal-probability</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Vijayawada-Sunny</th>
#       <td>6</td>
#       <td>2</td>
#       <td>0</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Vijayawada-Cloudy</th>
#       <td>1</td>
#       <td>5</td>
#       <td>2</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Vijayawada-Rainy</th>
#       <td>0</td>
#       <td>1</td>
#       <td>3</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Marginal-probability</th>
# ...

# %%
vs = vc = vr = 0
hs = hc = hr = 0
for i in range(3):
    vs += probabilityTable.iat[0,i]
    vc += probabilityTable.iat[1,i]
    vr += probabilityTable.iat[2,i]
    hs += probabilityTable.iat[i,0]
    hc += probabilityTable.iat[i,1]
    hr += probabilityTable.iat[i,2]

probabilityTable.iat[3,0] = hs
probabilityTable.iat[3,1] = hc
probabilityTable.iat[3,2] = hr
probabilityTable.iat[0,3] = vs
probabilityTable.iat[1,3] = vc
probabilityTable.iat[2,3] = vr
probabilityTable.iat[3,3] = 20
probabilityTable
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Hyderabad-Sunny</th>
#       <th>Hyderabad-Cloudy</th>
#       <th>Hyderabad-Rainy</th>
#       <th>Marginal-probability</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Vijayawada-Sunny</th>
#       <td>6</td>
#       <td>2</td>
#       <td>0</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>Vijayawada-Cloudy</th>
#       <td>1</td>
#       <td>5</td>
#       <td>2</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>Vijayawada-Rainy</th>
#       <td>0</td>
#       <td>1</td>
#       <td>3</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>Marginal-probability</th>
# ...

# %%
for i in range(4):
    for j in range(4):
        probabilityTable.iat[i,j]  = probabilityTable.iat[i,j]/20

probabilityTable
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Hyderabad-Sunny</th>
#       <th>Hyderabad-Cloudy</th>
#       <th>Hyderabad-Rainy</th>
#       <th>Marginal-probability</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Vijayawada-Sunny</th>
#       <td>0.3</td>
#       <td>0.1</td>
#       <td>0</td>
#       <td>0.4</td>
#     </tr>
#     <tr>
#       <th>Vijayawada-Cloudy</th>
#       <td>0.05</td>
#       <td>0.25</td>
#       <td>0.1</td>
#       <td>0.4</td>
#     </tr>
#     <tr>
#       <th>Vijayawada-Rainy</th>
#       <td>0</td>
#       <td>0.05</td>
#       <td>0.15</td>
#       <td>0.2</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# All the required prabability values can be obtained from the above table
